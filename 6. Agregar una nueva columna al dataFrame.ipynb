# %%
import pandas as pd

# %%
# Reading cvs file
df_exams = pd.read_csv("./Material/StudentsPerformance.csv")
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# # 1. Agregar una nueva columna

# %% [markdown]
# ## Agregar una nueva columna con un valor

# %%
# Agregar una nueva columna al dataFrame (valor constante)
df_exams["lenguage score"] = 70
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# ## 2. Agregar una nueva columna con Arrays
#
# El dataFrane tiene 1000 filas; por ello tenemos que crear un array con 1000 elementos

# %%
# Importar numpy
import numpy as np

# %%
# Crear un array con 1000 elementos
lenguage_score = np.arange(0, 1000)

# %%
# tamaño del array 
len(lenguage_score)
# Out:
# 1000

# %%
# Agregar una nueva columna al dataFrame con un array
df_exams["lenguage score"] = lenguage_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# Crear numeros enteros aleatorios entre 1 y 100
int_lenguage_score = np.random.randint(1, 100, size=1000)

# %%
len(int_lenguage_score)
# Out:
# 1000

# %%
min(int_lenguage_score)
# Out:
# 1

# %%
max(int_lenguage_score)
# Out:
# 99

# %%
df_exams["lenguage score"] = int_lenguage_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# Crear numeros aleatorios decimales entre 1 y 100
np.random.uniform(1, 100, size= 1000)
# Out:
# array([29.51711777, 99.9017596 , 21.78101733,  5.72071135, 95.31959489,
#        24.19239183, 72.21658554, 99.50182976, 85.5086734 , 97.54067222,
#         7.40022391, 23.14690697, 52.36338196, 69.53911376, 53.03491648,
#        88.82670971, 14.24198611,  5.18162556, 23.304304  , 93.93391041,
#        74.2482768 , 55.62253688, 42.63763411, 66.27424015, 44.58175246,
#        24.05743595, 56.55541143, 35.4266937 , 17.26793684, 36.47611429,
#        46.18017021, 97.67084915, 75.75425371, 84.50532587, 88.24977502,
#        85.02624563, 50.77753204, 39.44208009, 84.03166256, 15.09279224,
#        67.09712967,  3.06088094, 62.00000687, 81.11695394, 92.4415992 ,
#        34.02103081, 28.60081226, 81.67320172, 25.42344426, 79.25429727,
#        78.05405829, 37.21698165, 77.21731857, 82.95687096, 23.31432891,
#        44.44549054, 93.48793044, 50.93091339, 90.06368536, 53.37407916,
#        20.07632869, 24.04717671, 92.70910131, 49.06298226, 34.25249879,
# ...
