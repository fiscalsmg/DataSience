# %%
import pandas as pd

# %%
# reading and showing dataframe
df_exams = pd.read_csv("./Material/StudentsPerformance.csv")
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# # Crear index
#
# set_index() - nos ayuda a fijar un index
#
# sort_index() - nos ayuda a ordenar los index

# %%
import numpy as np
import random

# %%
# Crear valores no repetitivos para los index
new_index = np.arange(0,1000)

# %%
# Barajear/desordenar los indices 
random.shuffle(new_index)

# %%
new_index
# Out:
# array([ 68, 806, 324, 458, 890, 892, 820, 915, 872,  26,  33, 192, 781,
#        985, 106, 574, 550, 707, 751, 473,  47, 453, 706, 795, 782, 921,
#        169, 740,  39, 885, 289, 507, 323, 136, 282, 590, 742, 807,   2,
#        849, 864,  53, 508, 101, 894, 925, 113, 770, 393, 208, 315, 195,
#        109,  49,  59, 878, 754, 252, 676,  90, 724, 219, 745, 202, 968,
#        430, 691, 524, 997, 619, 361, 535, 247, 143, 303, 727, 466, 487,
#        360, 917,  95, 462, 981, 813, 858, 540, 484, 397, 823, 445, 577,
#        543, 120, 161, 182, 122, 329, 596, 913, 599, 527, 851, 253,  75,
#        134, 229, 165,  88, 273,  65, 166, 249, 664, 868, 352, 383, 632,
#        687, 221, 132, 606,  19, 140, 786, 358, 538,  76,  29, 415, 653,
#        956, 738, 951, 333, 634, 537, 638, 436, 180, 193, 476, 340, 684,
#        962, 304, 541, 493,  40, 420, 242, 719, 471, 741, 880, 174, 272,
#        911, 356, 720, 495, 387, 499, 559, 297,  66, 582,  73,  64, 854,
# ...

# %%
# Crear una nueva columna con los nuevos indices
df_exams["nuevo_index"] = new_index
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# # 2. set_index()

# %%
# Fijar columna nuevo_index como index

# CAMBIA el index UN INDEX NO PUEDE TENER REPETITIVO
df_exams.set_index("nuevo_index", inplace=True)

# %%
df_exams
# Out:
#              gender race/ethnicity parental level of education         lunch  \
# nuevo_index
# 68           female        group B           bachelor's degree      standard
# 806          female        group C                some college      standard
# 324          female        group B             master's degree      standard
# 458            male        group A          associate's degree  free/reduced
# 890            male        group C                some college      standard
# ...             ...            ...                         ...           ...
# 862          female        group E             master's degree      standard
# 835            male        group C                 high school  free/reduced
# 869          female        group C                 high school  free/reduced
# 768          female        group D                some college      standard
# 423          female        group D                some college  free/reduced
#
# ...

# %% [markdown]
# # 3. sort_index()

# %%
# Ordenar dataFrame por nuevo_index
df_exams.sort_index()
# Out:
#              gender race/ethnicity parental level of education         lunch  \
# nuevo_index
# 0              male        group D                some college      standard
# 1            female        group C            some high school  free/reduced
# 2            female        group D          associate's degree  free/reduced
# 3              male        group C                some college  free/reduced
# 4              male        group B          associate's degree      standard
# ...             ...            ...                         ...           ...
# 995            male        group E                some college  free/reduced
# 996          female        group D            some high school      standard
# 997            male        group B          associate's degree  free/reduced
# 998            male        group D          associate's degree      standard
# 999            male        group B          associate's degree  free/reduced
#
# ...

# %%
# Ordenar descendente por index
df_exams.sort_index(ascending=False, inplace=True)

# %%
df_exams
# Out:
#              gender race/ethnicity parental level of education         lunch  \
# nuevo_index
# 999            male        group B          associate's degree  free/reduced
# 998            male        group D          associate's degree      standard
# 997            male        group B          associate's degree  free/reduced
# 996          female        group D            some high school      standard
# 995            male        group E                some college  free/reduced
# ...             ...            ...                         ...           ...
# 4              male        group B          associate's degree      standard
# 3              male        group C                some college  free/reduced
# 2            female        group D          associate's degree  free/reduced
# 1            female        group C            some high school  free/reduced
# 0              male        group D                some college      standard
#
# ...
